# %% [markdown]
# <a href="https://colab.research.google.com/github/sourogithub/Final-yr-project-using-j2ee/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import cv2

# %%
data_dir = pathlib.Path('/content/sample_data/sample')
cat_image_count = len(list(data_dir.glob('cat1/*.jpg')))
dog_image_count = len(list(data_dir.glob('dog1/*.jpg')))
print(cat_image_count)
dogs = list(data_dir.glob('dog1/*'))
cats = list(data_dir.glob('cat1/*'))
PIL.Image.open(str(cats[2]))
# Out:
# 132
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F745DC00790>

# %%
batch_size = 32
img_height = 360
img_width = 480

train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)


class_names = train_ds.class_names
print(class_names)
# Out:
# Found 271 files belonging to 2 classes.
# Using 217 files for training.
# Found 271 files belonging to 2 classes.
# Using 54 files for validation.
# ['cat1', 'dog1']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
normalization_layer = layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_2 (Rescaling)     (None, 360, 480, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 360, 480, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 180, 240, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 180, 240, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 90, 120, 32)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 90, 120, 64)       18496
#
#  max_pooling2d_5 (MaxPooling  (None, 45, 60, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 172800)            0
#
#  dense_2 (Dense)             (None, 128)               22118528
#
#  dense_3 (Dense)             (None, 2)                 258
#
# ...
# Total params: 22,142,370
# Trainable params: 22,142,370
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 46s 6s/step - loss: 1.3433 - accuracy: 0.4470 - val_loss: 0.6700 - val_accuracy: 0.6296
# Epoch 2/10
# 7/7 [==============================] - 39s 6s/step - loss: 0.6544 - accuracy: 0.7051 - val_loss: 0.6773 - val_accuracy: 0.6667
# Epoch 3/10
# 7/7 [==============================] - 43s 6s/step - loss: 0.6025 - accuracy: 0.7051 - val_loss: 0.6463 - val_accuracy: 0.6111
# Epoch 4/10
# 7/7 [==============================] - 39s 6s/step - loss: 0.6161 - accuracy: 0.6313 - val_loss: 0.7740 - val_accuracy: 0.5556
# Epoch 5/10
# 7/7 [==============================] - 39s 6s/step - loss: 0.5030 - accuracy: 0.7696 - val_loss: 0.6565 - val_accuracy: 0.6111
# Epoch 6/10
# 7/7 [==============================] - 42s 6s/step - loss: 0.4337 - accuracy: 0.8111 - val_loss: 0.6269 - val_accuracy: 0.6852
# Epoch 7/10
# 7/7 [==============================] - 38s 5s/step - loss: 0.2853 - accuracy: 0.8894 - val_loss: 0.6268 - val_accuracy: 0.6481
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[1].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 7/7 [==============================] - 49s 6s/step - loss: 4.3017 - accuracy: 0.4839 - val_loss: 0.7970 - val_accuracy: 0.4074
# Epoch 2/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.6533 - accuracy: 0.6544 - val_loss: 0.7149 - val_accuracy: 0.5185
# Epoch 3/15
# 7/7 [==============================] - 44s 6s/step - loss: 0.6523 - accuracy: 0.6498 - val_loss: 1.0623 - val_accuracy: 0.3889
# Epoch 4/15
# 7/7 [==============================] - 45s 6s/step - loss: 0.6657 - accuracy: 0.6267 - val_loss: 0.7658 - val_accuracy: 0.4815
# Epoch 5/15
# 7/7 [==============================] - 44s 6s/step - loss: 0.6347 - accuracy: 0.6406 - val_loss: 0.7875 - val_accuracy: 0.5185
# Epoch 6/15
# 7/7 [==============================] - 47s 7s/step - loss: 0.6271 - accuracy: 0.6267 - val_loss: 0.9920 - val_accuracy: 0.5000
# Epoch 7/15
# 7/7 [==============================] - 44s 6s/step - loss: 0.5991 - accuracy: 0.6774 - val_loss: 0.8896 - val_accuracy: 0.5741
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
url1 = "/content/sample_data/test/pexels-saara-karoliina-2757055.jpg"
url = "/content/sample_data/test/pexels-helena-lopes-3908765.jpg"
url2 = "/content/sample_data/test/pexels-monicore-2888645.jpg"

#path = tf.keras.utils.get_file('dog', origin=url)

img = tf.keras.utils.load_img(
    url2, target_size=(img_height, img_width)
)
plt.imshow(img)

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# This image most likely belongs to dog1 with a 77.42 percent confidence.
